# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(rec_model_dir="C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/PaddleOCR/PP-OCRv5_server_rec_infer",
use_angle_cls=True,
text_recognition_model_name = "PP-OCRv5_mobile_rec"
)
# need to run only once to download and load model into memory
# img_path = '/Users/software/Desktop/credit_card_number_rec_Dataset/Val/5.png'
# result = ocr.ocr(img_path, cls=True)
# for idx in range(len(result)):
#     res = result[idx]
#     for line in res:
#         print(line)
# Out:
# C:\Users\baher\AppData\Local\Temp\ipykernel_20348\1764471203.py:3: UserWarning: `lang` and `ocr_version` will be ignored when model names or model directories are not `None`.
#   ocr = PaddleOCR(rec_model_dir="C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/PaddleOCR/PP-OCRv5_server_rec_infer",
# C:\Users\baher\AppData\Local\Temp\ipykernel_20348\1764471203.py:3: DeprecationWarning: The parameter `rec_model_dir` has been deprecated and will be removed in the future. Please use `text_recognition_model_dir` instead.
#   ocr = PaddleOCR(rec_model_dir="C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/PaddleOCR/PP-OCRv5_server_rec_infer",
# C:\Users\baher\AppData\Local\Temp\ipykernel_20348\1764471203.py:3: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
# ...

# %%
img_path = '../../paddleOCR/train_data/Test/2.png'
result = ocr.predict(img_path)
result[0]['rec_texts']
# Out:
# ['ааарррллряля']
