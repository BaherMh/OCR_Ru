# %%
import pandas as pd

# %%
csv_file = "../outputs/PaddleOCR/RusTwit/PaddleOCR_RusTwit_evaluated.csv"
df = pd.read_csv(csv_file)

# %%
df
# Out:
#       index                        answer                    prediction  \
# 0         0                  Щукин\nлемех                  Шукин лeMeх
# 1         1                         марля                      марля 26
# 2         2           влюбленный\nженский            ВЛЮБЛЕННЫЙ ЖЕНСКИЙ
# 3         3                      норвежец                      HopBeжec
# 4         4  Никонова\nхлев ствол\nЕнисей  Никонова хлев ствол Енисей 0
# ...     ...                           ...                           ...
# 2995   2995              перегиб откопать              нерегиб откопать
# 2996   2996                         19678                        19678
# 2997   2997                      Береснев                     BeрecneB
# 2998   2998                   гиперссылка                  риперссылка
# 2999   2999   провокационный\nЛапина панк   провокационный Лапина наHк
#
#       correct
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# ...
