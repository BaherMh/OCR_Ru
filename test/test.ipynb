# %%
import easyocr
reader = easyocr.Reader(['ru']) # this needs to run only once to load the model into memory
result = reader.readtext('4.png')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# d:\Users\baher\anaconda3\envs\ppocr\lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
" ".join(x[1] for x in result)
# Out:
# 'С ФНЕМ ЗНАНИИ;'
